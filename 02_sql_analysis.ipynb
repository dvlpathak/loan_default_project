# %%
import pandas as pd
from sqlalchemy import create_engine

# Change 'yourpassword' to your actual postgres password
engine = create_engine(
    "postgresql://postgres:pass123@localhost:5432/loan_db"
)

df = pd.read_csv('clean_loans.csv')
df.to_sql('loans', engine, if_exists='replace', index=False)

print(f"✓ Done! {len(df):,} rows loaded into PostgreSQL")
print("✓ Now open pgAdmin and write your queries!")
